# %%
# Problem Statement:
# You work in XYZ Company as a Python developer. The company officials want
# you to write code for an Agglomerative Clustering Problem.
# Data:
# [[5,3],
# [10,15],
# [15,12],
# [24,10],
# [30,30],
# [85,70],
# [71,80],
# [60,78],
# [70,55],
# [80,91],]
# Tasks To Be Performed:
# 1. Using the np.array function create an np array from the data given above
# 2. Generate a scatter plot for the data
# 3. Plot dendrogram to visualize the clustering linkage

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Create an np array from the given data
data = np.array([[5, 3],
                 [10, 15],
                 [15, 12],
                 [24, 10],
                 [30, 30],
                 [85, 70],
                 [71, 80],
                 [60, 78],
                 [70, 55],
                 [80, 91]])

# %%
# Step 2: Generate a scatter plot for the data
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c='blue', marker='o', label='Data Points')
plt.title('Scatter Plot of Data Points')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 3. Plot dendrogram to visualize the clustering linkage

linkage_matrix = linkage(data,method='ward')
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix)
plt.title('Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

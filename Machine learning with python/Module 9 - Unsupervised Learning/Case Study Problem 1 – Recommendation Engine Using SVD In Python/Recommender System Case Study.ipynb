# %%
import pandas as pd
import numpy as np
from scipy.sparse.linalg import svds
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise import SVD
from surprise.model_selection import train_test_split

# %%
#a. Load the ‘ratings’ and ‘movies’ datasets which is a part of ‘MovieLense’

ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')

# %%
#b. Find the unique number of users and movies in the ‘ratings’ dataset

users = ratings['userId'].unique()
uni_movies = ratings['movieId'].unique()

num_users = len(users)
num_movies = len(uni_movies)

print(f'number of unique users: {num_users}')
print(f'number of unique movies: {num_movies}')
# Out:
# number of unique users: 7120
# number of unique movies: 14026

# %%
#c. Create a rating matrix for the ‘ratings’ dataset and store it in ‘Ratings’

Ratings = np.zeros((num_users,num_movies))

# Filling the rating matrix with actual ratings
for index, row in ratings.iterrows():
    user_index = np.where(users == row['userId'])[0][0]
    movie_index = np.where(uni_movies == row['movieId'])[0][0]
    Ratings[user_index, movie_index] = row['rating']

# %%
#d. Load the ‘ratings’ dataset as SVD’s Dataset object and compute 3-fold cross-validation
# using the SVD object


# Define the Reader object
reader = Reader(rating_scale=(1, 5))

# Load the data into the Dataset object
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# Define the SVD algorithm
algo = SVD()

# Run 3-fold cross-validation
results = cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

# Print the results
print('RMSE:', results['test_rmse'].mean())
print('MAE:', results['test_mae'].mean())
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8463  0.8441  0.8452  0.8452  0.0009
# MAE (testset)     0.6477  0.6475  0.6471  0.6474  0.0002
# Fit time          20.26   20.36   20.92   20.52   0.29
# Test time         6.93    7.61    8.16    7.56    0.50
# RMSE: 0.845201903054532
# MAE: 0.6474057786119753

# %%
#e. Find all the movies rated as 5 stars by user id ‘5’ and store it in ‘ratings_1’ data frame

# Filter ratings dataframe by user id 5 and rating of 5
ratings_1 = ratings[(ratings['userId'] == 5) & (ratings['rating'] == 5)]

# Join with movies dataframe to get movie names
ratings_1 = pd.merge(ratings_1, movies, on='movieId', how='inner')[['title', 'genres']]

ratings_1
# Out:
#                                                 title  \
# 0                      American President, The (1995)
# 1                           Mr. Holland's Opus (1995)
# 2                                Birdcage, The (1996)
# 3                                    Apollo 13 (1995)
# 4           Star Wars: Episode IV - A New Hope (1977)
# 5                    Shawshank Redemption, The (1994)
# 6                               Lion King, The (1994)
# 7                                     Maverick (1994)
# 8                                        Speed (1994)
# 9                                    True Lies (1994)
# 10                                        Dave (1993)
# 11                                   Firm, The (1993)
# 12                               Fugitive, The (1993)
# 13                              Mrs. Doubtfire (1993)
# 14                                Philadelphia (1993)
# 15                          Secret Garden, The (1993)
# 16                                     Aladdin (1992)
# 17                  Terminator 2: Judgment Day (1991)
# 18                          Dances with Wolves (1990)
# 19             Snow White and the Seven Dwarfs (1937)
# 20                        Beauty and the Beast (1991)
# 21     Mystery Science Theater 3000: The Movie (1996)
# 22  Wallace & Gromit: The Best of Aardman Animatio...
# 23                                     Twister (1996)
# 24               Independence Day (a.k.a. ID4) (1996)
# 25                                      Ransom (1996)
# 26                                Mary Poppins (1964)
# 27                         Sound of Music, The (1965)
# 28                                    Die Hard (1988)
# 29                        Fish Called Wanda, A (1988)
# 30                Monty Python's Life of Brian (1979)
# 31                  E.T. the Extra-Terrestrial (1982)
# 32             Monty Python and the Holy Grail (1975)
# 33  Star Wars: Episode V - The Empire Strikes Back...
# 34  Raiders of the Lost Ark (Indiana Jones and the...
# 35  Star Wars: Episode VI - Return of the Jedi (1983)
# 36          Indiana Jones and the Last Crusade (1989)
# 37                               Jerry Maguire (1996)
#
#                                              genres
# 0                              Comedy|Drama|Romance
# 1                                             Drama
# 2                                            Comedy
# 3                              Adventure|Drama|IMAX
# 4                           Action|Adventure|Sci-Fi
# 5                                       Crime|Drama
# 6   Adventure|Animation|Children|Drama|Musical|IMAX
# 7                          Adventure|Comedy|Western
# 8                           Action|Romance|Thriller
# 9          Action|Adventure|Comedy|Romance|Thriller
# 10                                   Comedy|Romance
# 11                                   Drama|Thriller
# 12                                         Thriller
# 13                                     Comedy|Drama
# 14                                            Drama
# 15                                   Children|Drama
# 16      Adventure|Animation|Children|Comedy|Musical
# 17                                    Action|Sci-Fi
# 18                          Adventure|Drama|Western
# 19         Animation|Children|Drama|Fantasy|Musical
# 20  Animation|Children|Fantasy|Musical|Romance|IMAX
# 21                                    Comedy|Sci-Fi
# 22                       Adventure|Animation|Comedy
# 23                Action|Adventure|Romance|Thriller
# 24                 Action|Adventure|Sci-Fi|Thriller
# 25                                   Crime|Thriller
# 26                  Children|Comedy|Fantasy|Musical
# 27                                  Musical|Romance
# 28                            Action|Crime|Thriller
# 29                                     Comedy|Crime
# 30                                           Comedy
# 31                            Children|Drama|Sci-Fi
# 32                         Adventure|Comedy|Fantasy
# 33                          Action|Adventure|Sci-Fi
# 34                                 Action|Adventure
# 35                          Action|Adventure|Sci-Fi
# 36                                 Action|Adventure
# 37                                    Drama|Romance

# %%
#f. Create a shallow copy of the ‘movies’ dataset and store the result in ‘user_5’

user_5 = movies.copy()

# %%
#g. Train a recommender system using the SVD object and predict the ratings for user id ‘5’

user_5['predicted_rating'] = user_5['movieId'].apply(lambda x: algo.predict(5, x).est)

# %%
#h. Print the top10 movie recommendations for the user id ‘5’

top10_movies = user_5.sort_values('predicted_rating', ascending=False)[:10]

top10_movies
# Out:
#       movieId                                              title  \
# 523       527                            Schindler's List (1993)
# 3340     3429                           Creature Comforts (1989)
# 352       356                                Forrest Gump (1994)
# 1173     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 4897     4993  Lord of the Rings: The Fellowship of the Ring,...
# 2500     2585  Lovers of the Arctic Circle, The (Los Amantes ...
# 108       110                                  Braveheart (1995)
# 257       260          Star Wars: Episode IV - A New Hope (1977)
# 5853     5952      Lord of the Rings: The Two Towers, The (2002)
# 315       318                   Shawshank Redemption, The (1994)
#
#                         genres  predicted_rating
# 523                  Drama|War          5.000000
# 3340          Animation|Comedy          5.000000
# 352   Comedy|Drama|Romance|War          5.000000
# 1173          Action|Adventure          5.000000
# 4897         Adventure|Fantasy          5.000000
# 2500             Drama|Romance          4.990621
# 108           Action|Drama|War          4.976910
# 257    Action|Adventure|Sci-Fi          4.972063
# 5853         Adventure|Fantasy          4.951999
# 315                Crime|Drama          4.939736
